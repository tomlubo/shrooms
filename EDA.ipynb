# %%
import pandas as pd
from pathlib import Path
import os
from PIL import Image
import numpy as np

data_path = './data/'

train_meta = pd.read_csv(os.path.join(data_path, 'train.csv'))
val_meta = pd.read_csv(os.path.join(data_path, 'val.csv'))
test_meta = pd.read_csv(os.path.join(data_path, 'test.csv'))

# %%
sample_path = train_meta.iloc[0]['image_path']
pil_image = Image.open(data_path + sample_path)

arr = np.array(pil_image)
print(arr.shape)
pil_image
# Out:
# (345, 500, 3)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x345>

# %%
for path in train_meta['image_path']:
    shape = np.array(Image.open(data_path + path)).shape
    print(shape)
# Out:
# (345, 500, 3)
# (333, 500, 3)
# (500, 375, 3)
# (375, 500, 3)
# (500, 375, 3)
# (640, 550, 3)
# (500, 375, 3)
# (500, 465, 3)
# (628, 640, 3)
# (500, 375, 3)
# (375, 500, 3)
# (427, 640, 3)
# (225, 500, 3)
# (281, 500, 3)
# (500, 375, 3)
# (500, 365, 3)
# (360, 640, 3)
# (375, 500, 3)
# (500, 375, 3)
# (500, 335, 3)
# (350, 500, 3)
# (500, 447, 3)
# (500, 375, 3)
# (375, 500, 3)
# (480, 640, 3)
# (375, 500, 3)
# (333, 500, 3)
# (480, 640, 3)
# (426, 640, 3)
# (375, 500, 3)
# (480, 640, 3)
# (333, 500, 3)
# (478, 640, 3)
# (500, 281, 3)
# (480, 640, 3)
# (333, 500, 3)
# (500, 375, 3)
# (500, 460, 3)
# (500, 375, 3)
# (400, 500, 3)
# (480, 640, 3)
# (500, 296, 3)
# (375, 500, 3)
# (375, 500, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (500, 375, 3)
# (500, 334, 3)
# (500, 250, 3)
# (500, 375, 3)
# (500, 375, 3)
# (333, 500, 3)
# (500, 375, 3)
# (500, 281, 3)
# (500, 375, 3)
# (500, 375, 3)
# (480, 640, 3)
# (500, 375, 3)
# (500, 375, 3)
# (500, 281, 3)
# (500, 418, 3)
# ...
